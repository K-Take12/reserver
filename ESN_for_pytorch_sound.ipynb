# %%
# ドライブのマウントdrive.mount('/content/drive')

# フォルダパス設定
data_dir = '/content/drive/MyDrive/Lyon_decimation_128'

# %%
import os
import numpy as np
from scipy.io import loadmat
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
from torch.utils.data import TensorDataset, DataLoader, random_split
from google.colab import drive

# %%
### データセットの準備
features = []
labels = []


### ファイルを読み込む
for file_name in os.listdir(data_dir):
    if file_name.endswith(".mat"):
        # ファイル名からラベルを取得
        label = int(file_name.split('_')[-1][1:-4])  # 'd〇' の〇を取得

        # ファイルを読み込む
        mat = scipy.io.loadmat(os.path.join(data_dir, file_name))
        spec = mat['spec']  # コクリアグラムデータ

        # 特徴量とラベルを追加
        features.append(spec)
        labels.append(label)


### データの調整　最大時間長を持つデータに０パディングで合わせる
# 最大時間長を取得
max_len = max(spec.shape[1] for spec in features)

# ゼロパディングして特徴量を統一
padded_features = np.array([
    np.pad(spec, ((0, 0), (0, max_len - spec.shape[1])), mode='constant')
    for spec in features
])

# ラベルはそのままNumPy配列に変換
labels = np.array(labels)

# 確認用
print("パディング後の特徴量形状:", padded_features.shape)
print("ラベル形状:", labels.shape)
# Out:
# パディング後の特徴量形状: (500, 77, 130)
# ラベル形状: (500,)

# %%
### データセットの作成
dataset = torch.utils.data.TensorDataset(
    torch.tensor(padded_features, dtype=torch.float32),
    torch.tensor(labels, dtype=torch.long)
)

# 訓練データと検証データの割合
train_size = int(0.7 * len(dataset))  # 訓練データ80%
val_size = len(dataset) - train_size  # 検証データ20%

# データセットを訓練用と検証用にランダムに分割
train_dataset, val_dataset = random_split(dataset, [train_size, val_size])

# DataLoaderを作成
batch_size = 32  # バッチサイズの設定

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# 訓練データと検証データの確認
for batch_features, batch_labels in train_loader:
    print("訓練バッチの特徴量形状:", batch_features.shape)
    print("訓練バッチのラベル形状:", batch_labels.shape)
    print("訓練データ数", len(train_dataset))
    break

for batch_features, batch_labels in val_loader:
    print("検証バッチの特徴量形状:", batch_features.shape)
    print("検証バッチのラベル形状:", batch_labels.shape)
    print("検証データ数", len(val_dataset))
    break
# Out:
# 訓練バッチの特徴量形状: torch.Size([32, 77, 130])
# 訓練バッチのラベル形状: torch.Size([32])
# 訓練データ数 350
# 検証バッチの特徴量形状: torch.Size([32, 77, 130])
# 検証バッチのラベル形状: torch.Size([32])
# 検証データ数 150

# %% [markdown]
# **以下より学習モデル**

# %%
# 恒等写像
def identity(x):
    return x # pytorchのテンソルをそのまま処理可能


# 入力層
class Input(nn.Module):
    def __init__(self, N_u, N_x, input_scale, seed=0):
        '''
        param N_u: 入力次元
        param N_x: リザバーのノード数
        param input_scale: 入力スケーリング
        '''
        super(Input, self).__init__()
        # 一様分布に従う乱数
        torch.manual_seed(seed)
        self.Win = nn.Parameter(torch.empty((N_u, N_x)).uniform_(-input_scale, input_scale))
        self.Win.requires_grad = False  # 勾配更新を不要にする

    def get_weight_matrix(self):
        # 入力行列Winを返す
        return self.Win

# %%
class Reservoir(nn.Module):
    def __init__(self, N_x, density, rho, activation_func,  seed):
        '''
        param N_x: リザバーのノード数
        param density: ネットワークの結合密度
        param rho: リカレント結合重み行列のスペクトル半径
        param activation_func: ノードの活性化関数 (torch.nn.functional)
        param leaking_rate: leaky integratorモデルのリーク率
        param seed: 乱数の種
        '''
        super(Reservoir, self).__init__()
        self.seed = seed
        self.N_x = N_x
        self.W = self.make_connection_pytorch(N_x, density, rho, seed)
        self.W = nn.Parameter(self.W)  # Wをnn.Parameterとしてラップ
        self.x = torch.zeros(N_x, dtype=torch.float32)  # リザバー状態ベクトルの初期化
        self.activation_func = activation_func
        self.W.requires_grad = False  # リザバーの重みは訓練しない

    @staticmethod
    def make_connection_pytorch(N_x, density, rho, seed):
        torch.manual_seed(seed)

        # ランダムな接続行列の生成
        connection = torch.bernoulli(torch.full((N_x, N_x), density))
        rec_scale = 1.0
        W = connection * (torch.rand((N_x, N_x)) * 2 * rec_scale - rec_scale)

        # Wが空でないことを確認
        if W.numel() == 0:
            raise ValueError("Weight matrix W is empty. Please check the matrix generation process.")

        # スペクトル半径を計算
        eigenvalues = torch.linalg.eigvals(W)
        if eigenvalues.numel() == 0:
            raise ValueError("Eigenvalues are empty. Check the matrix W.")

        sp_radius = torch.max(torch.abs(eigenvalues.real))

        # スペクトル半径をrhoにスケーリング
        W *= rho / sp_radius

        return W

    def get_weight_matrix_W(self):
        # 重み行列Wを返す
        return self.W

# %%
class Output(nn.Module):
    def __init__(self, N_x, N_y, seed=0):
        '''
        param N_x: リザバーのノード数
        param N_y: 出力次元
        param seed: 乱数の種
        '''
        super(Output, self).__init__()
        # 正規分布に従う乱数で初期化
        torch.manual_seed(seed)
        self.Wout = nn.Parameter(torch.randn( N_x, N_y, dtype=torch.float32))
        self.Wout.requires_grad = True


    def get_weight_matrix_wout(self):
        # 出力行列Woutを返す
        return self.Wout


    def setweight(self, Wout_opt):
        '''
        学習済みの出力結合重み行列を設定
        param Wout_opt: 新しい重み行列 (torch.Tensor)
        '''
        if not isinstance(Wout_opt, torch.Tensor):
            raise ValueError("Wout_opt must be a torch.Tensor.")
        self.Wout = Wout_opt

# %%
# 未修正
class Feedback:
    def __init__(self, N_y, N_x, fb_scale, seed=0):
        '''
        param N_y: 出力次元
        param N_x: リザバーのノード数
        param fb_scale: フィードバックスケーリング
        param seed: 乱数の種
        '''
        # 一様分布に従う乱数で初期化
        torch.manual_seed(seed)
        self.Wfb = (torch.rand(N_x, N_y, dtype=torch.float32) * 2 * fb_scale - fb_scale)

    def __call__(self, y):
        '''
        param y: N_y次元のベクトル (torch.Tensor)
        return: N_x次元のベクトル (torch.Tensor)
        '''
        return torch.matmul(self.Wfb, y)

# %%
class ESN(nn.Module):
    def __init__(self, N_u, N_y, N_x, density=0.05, input_scale=1.0e+4, rho=0.95, activation_func=torch.tanh, fb_scale=None, fb_seed=0, noise_level=None, leaking_rate=0.7, output_func=None, classification=False, average_window=None, seed = 40):
        super(ESN, self).__init__()

        # モジュールの初期化
        self.Input = Input(N_u, N_x, input_scale)  # 入力層
        self.Reservoir = Reservoir(N_x, density, rho, activation_func, seed) # リザバー層
        self.x_res = torch.zeros(N_x, dtype=torch.float32)  # リザバー状態ベクトルの初期化
        self.Output = Output(N_x, N_y) # リードアウトを取得


        self.N_u = N_u
        self.N_y = N_y
        self.N_x = N_x
        self.activation_func = activation_func
        self.output_func = output_func if output_func is not None else lambda x: x
        self.classification = classification
        self.alpha = leaking_rate
        self.Input.requires_grad = False
        self.Reservoir.requires_grad = False

        # 出力層からのリザバーへのフィードバックの有無
        if fb_scale is None:
            self.Feedback = None
        else:
            self.Feedback = Feedback(N_y, N_x, fb_scale, fb_seed)

        # リザバーの状態更新にノイズを加えるか
        if noise_level is None:
            self.noise = None
        else:
            self.noise = torch.rand(N_x, 1) * noise_level * 2 - noise_level  # -noise_level to +noise_level

        # 分類問題の場合の設定
        if classification:
            if average_window is None:
                raise ValueError('Window for time average is not given!')
            else:
                self.window = torch.zeros((average_window, self.N_x))

        # リザバー状態の初期化
        self.reset_reservoir_state()

    def forward(self, u):
        '''
        param u: N_u次元のベクトル (torch.Tensor)
        return: N_y次元のベクトル (torch.Tensor)

        '''

        # 入力層の行列Winを取得
        Win = self.Input.get_weight_matrix()

        # 順伝播：入力uとWinを掛け算して、リザバー状態を更新
        x_in = torch.matmul(u, Win)

        # リザバーの行列Wを取得
        W = self.Reservoir.get_weight_matrix_W()


        # 順伝播：
        x_res =  (1.0 - self.alpha) * self.x_res + self.alpha * self.activation_func(torch.matmul(W, self.x_res) + x_in)

        # リードアウトの行列Woutを取得
        Wout = self.Output.get_weight_matrix_wout()
        #print("Wout requires_grad:", Wout.requires_grad)

        #print(Wout)
        # 順伝播：
        y = torch.matmul(x_res, Wout)



        # フィードバックがある場合の処理
        if self.Feedback is not None:
            self.x += self.Feedback(self.x)

        # ノイズの追加
        if self.noise is not None:
            self.x += self.noise

        # 学習前のモデル出力

        return y

    def reset_reservoir_state(self):
        '''リザバー状態ベクトルの初期化'''
        self.x = torch.zeros(self.N_x)

# %%
import torch
import torch.optim as optim
import torch.nn as nn
from sklearn.metrics import accuracy_score

# モデルのインスタンス化
N_u = 130  # 入力次元数 (77, 130 の形状から130)
N_y = len(np.unique(labels))  # クラス数
N_x = 100  # リザバーのサイズ (例として200に設定)

model = ESN(N_u=N_u, N_y=N_y, N_x=N_x)

# 最適化器と損失関数の設定
optimizer = optim.Adam(model.parameters(), lr=0.01)
criterion = nn.CrossEntropyLoss()

# 損失を記録するリスト
train_losses = []
val_losses = []

# 精度を記録するリスト
train_accuracies = []
val_accuracies = []

# 訓練ループ
num_epochs = 150
for epoch in range(num_epochs):
    model.train()  # 訓練モード
    train_outputs = [] # 混同行列用
    train_labels = [] # 混同行列用
    running_loss = 0.0

    # 訓練データをバッチごとに処理
    for batch_features, batch_labels in train_loader:
        optimizer.zero_grad()

        # 順伝播
        outputs = model(batch_features)

        # 順伝播時に出力形状を確認
        outputs = model(batch_features)
        # 各チャネルに対して最も確率が高いクラスを選択
        outputs = torch.mean(outputs, dim=1)

        # 損失計算
        loss = criterion(outputs, batch_labels)

        # バックプロパゲーション
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

        train_outputs.extend(torch.argmax(outputs, dim=1).tolist())
        train_labels.extend(batch_labels.tolist())

    # エポック毎の平均損失を表示
    avg_train_loss = running_loss / len(train_loader)
    train_losses.append(avg_train_loss)
    print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {avg_train_loss:.4f}")
    trin_accuracy = accuracy_score(train_labels, train_outputs)
    print(f"Train Accuracy: {trin_accuracy:.4f}")
    train_accuracies.append(trin_accuracy)

    # 検証
    model.eval()  # 評価モード
    val_outputs = []
    val_labels = []
    running_val_loss = 0.0
    with torch.no_grad():
        for batch_features, batch_labels in val_loader:
            # 順伝播
            outputs = model(batch_features)
            outputs = torch.mean(outputs, dim=1)
            _, predicted = torch.max(outputs, 1)
            val_outputs.extend(predicted.numpy())
            val_labels.extend(batch_labels.numpy())

            loss = criterion(outputs, batch_labels)
            running_val_loss += loss.item()

    avg_val_loss = running_val_loss / len(val_loader)
    val_losses.append(avg_val_loss)
    print(f"Validation Loss: {avg_val_loss:.4f}")


    val_accuracy = accuracy_score(val_labels, val_outputs)
    print(f"Validation Accuracy: {val_accuracy:.4f}")
    val_accuracies.append(val_accuracy)

from sklearn.metrics import confusion_matrix
import seaborn as sns

# 混同行列を計算
cm = confusion_matrix(val_labels, val_outputs)

# 訓練データに対する混同行列
cm_train = confusion_matrix(train_labels, train_outputs)

# 訓練データの混同行列を描画
plt.figure(figsize=(8, 6))
sns.heatmap(cm_train, annot=True, fmt="d", cmap="Blues", xticklabels=[str(i) for i in range(10)], yticklabels=[str(i) for i in range(10)])
plt.xlabel('predict')
plt.ylabel('real')
plt.title('con_train')
plt.show()

# 混同行列を描画
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=[str(i) for i in range(10)], yticklabels=[str(i) for i in range(10)])
plt.xlabel('predict')
plt.ylabel('real')
plt.title('con_val')
plt.show()


# 訓練損失
plt.figure(figsize=(8, 6))
plt.plot(range(1, num_epochs+1), train_losses, label='Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# 検証損失
plt.figure(figsize=(8, 6))
plt.plot(range(1, num_epochs+1), val_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Validation Loss over Epochs')
plt.legend()

# 訓練制度
plt.figure(figsize=(8, 6))
plt.plot(range(1, num_epochs + 1), train_accuracies, label='Training Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training Accuracy over Epochs')
plt.legend()
plt.show()

# 検証制度
plt.figure(figsize=(8, 6))
plt.plot(range(1, num_epochs + 1), val_accuracies, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Validation Accuracy over Epochs')
# Out:
# Epoch [1/150], Loss: 4.9630
# Train Accuracy: 0.1171
# Validation Loss: 4.1503
# Validation Accuracy: 0.0867
# Epoch [2/150], Loss: 3.0850
# Train Accuracy: 0.1971
# Validation Loss: 2.9369
# Validation Accuracy: 0.1667
# Epoch [3/150], Loss: 2.5159
# Train Accuracy: 0.2571
# Validation Loss: 2.4766
# Validation Accuracy: 0.1733
# Epoch [4/150], Loss: 2.1690
# Train Accuracy: 0.2829
# Validation Loss: 2.3157
# Validation Accuracy: 0.2200
# Epoch [5/150], Loss: 1.9823
# Train Accuracy: 0.3286
# Validation Loss: 2.1133
# Validation Accuracy: 0.2400
# Epoch [6/150], Loss: 1.8836
# Train Accuracy: 0.3714
# Validation Loss: 2.0669
# Validation Accuracy: 0.2733
# Epoch [7/150], Loss: 1.7849
# Train Accuracy: 0.3771
# Validation Loss: 2.0012
# Validation Accuracy: 0.3267
# Epoch [8/150], Loss: 1.7021
# Train Accuracy: 0.4086
# Validation Loss: 1.9115
# Validation Accuracy: 0.3600
# Epoch [9/150], Loss: 1.6494
# Train Accuracy: 0.4314
# Validation Loss: 1.8629
# Validation Accuracy: 0.3800
# Epoch [10/150], Loss: 1.6026
# Train Accuracy: 0.4343
# Validation Loss: 1.8148
# Validation Accuracy: 0.3800
# Epoch [11/150], Loss: 1.5624
# Train Accuracy: 0.4629
# Validation Loss: 1.7473
# Validation Accuracy: 0.4200
# Epoch [12/150], Loss: 1.5250
# Train Accuracy: 0.4857
# Validation Loss: 1.7417
# Validation Accuracy: 0.4067
# Epoch [13/150], Loss: 1.4737
# Train Accuracy: 0.4943
# Validation Loss: 1.6684
# Validation Accuracy: 0.4800
# Epoch [14/150], Loss: 1.4363
# Train Accuracy: 0.5200
# Validation Loss: 1.6488
# Validation Accuracy: 0.4733
# Epoch [15/150], Loss: 1.3913
# Train Accuracy: 0.5171
# Validation Loss: 1.5985
# Validation Accuracy: 0.5200
# Epoch [16/150], Loss: 1.3666
# Train Accuracy: 0.5429
# Validation Loss: 1.6130
# Validation Accuracy: 0.4667
# Epoch [17/150], Loss: 1.3283
# Train Accuracy: 0.5429
# Validation Loss: 1.5388
# Validation Accuracy: 0.5400
# Epoch [18/150], Loss: 1.2984
# Train Accuracy: 0.5571
# Validation Loss: 1.5206
# Validation Accuracy: 0.5400
# Epoch [19/150], Loss: 1.2797
# Train Accuracy: 0.5771
# Validation Loss: 1.5122
# Validation Accuracy: 0.5133
# Epoch [20/150], Loss: 1.2621
# Train Accuracy: 0.5686
# Validation Loss: 1.4609
# Validation Accuracy: 0.5733
# Epoch [21/150], Loss: 1.2385
# Train Accuracy: 0.5971
# Validation Loss: 1.4779
# Validation Accuracy: 0.5267
# Epoch [22/150], Loss: 1.2135
# Train Accuracy: 0.5971
# Validation Loss: 1.4434
# Validation Accuracy: 0.5867
# Epoch [23/150], Loss: 1.1893
# Train Accuracy: 0.6171
# Validation Loss: 1.3977
# Validation Accuracy: 0.5800
# Epoch [24/150], Loss: 1.1709
# Train Accuracy: 0.6229
# Validation Loss: 1.4154
# Validation Accuracy: 0.5867
# Epoch [25/150], Loss: 1.1601
# Train Accuracy: 0.6057
# Validation Loss: 1.3502
# Validation Accuracy: 0.5933
# Epoch [26/150], Loss: 1.1544
# Train Accuracy: 0.6086
# Validation Loss: 1.3449
# Validation Accuracy: 0.5933
# Epoch [27/150], Loss: 1.1256
# Train Accuracy: 0.6400
# Validation Loss: 1.3548
# Validation Accuracy: 0.5933
# Epoch [28/150], Loss: 1.1099
# Train Accuracy: 0.6371
# Validation Loss: 1.3299
# Validation Accuracy: 0.5800
# Epoch [29/150], Loss: 1.0954
# Train Accuracy: 0.6657
# Validation Loss: 1.3034
# Validation Accuracy: 0.5933
# Epoch [30/150], Loss: 1.0706
# Train Accuracy: 0.6571
# Validation Loss: 1.2966
# Validation Accuracy: 0.5800
# Epoch [31/150], Loss: 1.0588
# Train Accuracy: 0.6629
# Validation Loss: 1.2552
# Validation Accuracy: 0.6067
# Epoch [32/150], Loss: 1.0409
# Train Accuracy: 0.6714
# Validation Loss: 1.2878
# Validation Accuracy: 0.5933
# Epoch [33/150], Loss: 1.0196
# Train Accuracy: 0.6886
# Validation Loss: 1.2155
# Validation Accuracy: 0.6133
# Epoch [34/150], Loss: 1.0137
# Train Accuracy: 0.6800
# Validation Loss: 1.2330
# Validation Accuracy: 0.6133
# Epoch [35/150], Loss: 1.0024
# Train Accuracy: 0.6886
# Validation Loss: 1.2210
# Validation Accuracy: 0.6200
# Epoch [36/150], Loss: 0.9833
# Train Accuracy: 0.6914
# Validation Loss: 1.2033
# Validation Accuracy: 0.6267
# Epoch [37/150], Loss: 0.9782
# Train Accuracy: 0.6857
# Validation Loss: 1.1813
# Validation Accuracy: 0.6267
# Epoch [38/150], Loss: 0.9640
# Train Accuracy: 0.6914
# Validation Loss: 1.1763
# Validation Accuracy: 0.6267
# Epoch [39/150], Loss: 0.9451
# Train Accuracy: 0.7000
# Validation Loss: 1.1828
# Validation Accuracy: 0.6200
# Epoch [40/150], Loss: 0.9390
# Train Accuracy: 0.7257
# Validation Loss: 1.1593
# Validation Accuracy: 0.6467
# Epoch [41/150], Loss: 0.9231
# Train Accuracy: 0.7171
# Validation Loss: 1.1459
# Validation Accuracy: 0.6600
# Epoch [42/150], Loss: 0.9308
# Train Accuracy: 0.7171
# Validation Loss: 1.1352
# Validation Accuracy: 0.6400
# Epoch [43/150], Loss: 0.9144
# Train Accuracy: 0.7257
# Validation Loss: 1.1343
# Validation Accuracy: 0.6400
# Epoch [44/150], Loss: 0.8969
# Train Accuracy: 0.7200
# Validation Loss: 1.1020
# Validation Accuracy: 0.6600
# Epoch [45/150], Loss: 0.8923
# Train Accuracy: 0.7143
# Validation Loss: 1.1143
# Validation Accuracy: 0.6667
# Epoch [46/150], Loss: 0.8733
# Train Accuracy: 0.7314
# Validation Loss: 1.0825
# Validation Accuracy: 0.6667
# Epoch [47/150], Loss: 0.8627
# Train Accuracy: 0.7429
# Validation Loss: 1.0785
# Validation Accuracy: 0.6733
# Epoch [48/150], Loss: 0.8632
# Train Accuracy: 0.7200
# Validation Loss: 1.0978
# Validation Accuracy: 0.6733
# Epoch [49/150], Loss: 0.8509
# Train Accuracy: 0.7343
# Validation Loss: 1.0570
# Validation Accuracy: 0.6933
# Epoch [50/150], Loss: 0.8436
# Train Accuracy: 0.7371
# Validation Loss: 1.0624
# Validation Accuracy: 0.6800
# Epoch [51/150], Loss: 0.8339
# Train Accuracy: 0.7543
# Validation Loss: 1.0505
# Validation Accuracy: 0.6867
# Epoch [52/150], Loss: 0.8189
# Train Accuracy: 0.7657
# Validation Loss: 1.0373
# Validation Accuracy: 0.6933
# Epoch [53/150], Loss: 0.8115
# Train Accuracy: 0.7429
# Validation Loss: 1.0285
# Validation Accuracy: 0.7200
# Epoch [54/150], Loss: 0.8136
# Train Accuracy: 0.7514
# Validation Loss: 1.0274
# Validation Accuracy: 0.7067
# Epoch [55/150], Loss: 0.8069
# Train Accuracy: 0.7457
# Validation Loss: 1.0103
# Validation Accuracy: 0.7067
# Epoch [56/150], Loss: 0.8036
# Train Accuracy: 0.7571
# Validation Loss: 1.0343
# Validation Accuracy: 0.6733
# Epoch [57/150], Loss: 0.7919
# Train Accuracy: 0.7600
# Validation Loss: 1.0066
# Validation Accuracy: 0.7000
# Epoch [58/150], Loss: 0.7754
# Train Accuracy: 0.7686
# Validation Loss: 1.0171
# Validation Accuracy: 0.7133
# Epoch [59/150], Loss: 0.7714
# Train Accuracy: 0.7600
# Validation Loss: 0.9771
# Validation Accuracy: 0.7200
# Epoch [60/150], Loss: 0.7644
# Train Accuracy: 0.7771
# Validation Loss: 0.9747
# Validation Accuracy: 0.7333
# Epoch [61/150], Loss: 0.7655
# Train Accuracy: 0.7571
# Validation Loss: 0.9766
# Validation Accuracy: 0.6867
# Epoch [62/150], Loss: 0.7474
# Train Accuracy: 0.7686
# Validation Loss: 1.0020
# Validation Accuracy: 0.7467
# Epoch [63/150], Loss: 0.7435
# Train Accuracy: 0.7829
# Validation Loss: 0.9464
# Validation Accuracy: 0.7333
# Epoch [64/150], Loss: 0.7451
# Train Accuracy: 0.7886
# Validation Loss: 0.9889
# Validation Accuracy: 0.7200
# Epoch [65/150], Loss: 0.7336
# Train Accuracy: 0.7829
# Validation Loss: 0.9444
# Validation Accuracy: 0.7267
# Epoch [66/150], Loss: 0.7307
# Train Accuracy: 0.7657
# Validation Loss: 0.9802
# Validation Accuracy: 0.7200
# Epoch [67/150], Loss: 0.7120
# Train Accuracy: 0.7829
# Validation Loss: 0.9285
# Validation Accuracy: 0.7200
# Epoch [68/150], Loss: 0.7214
# Train Accuracy: 0.7800
# Validation Loss: 0.9462
# Validation Accuracy: 0.7133
# Epoch [69/150], Loss: 0.7120
# Train Accuracy: 0.7886
# Validation Loss: 0.9204
# Validation Accuracy: 0.7600
# Epoch [70/150], Loss: 0.7002
# Train Accuracy: 0.8029
# Validation Loss: 0.9452
# Validation Accuracy: 0.7200
# Epoch [71/150], Loss: 0.6928
# Train Accuracy: 0.7971
# Validation Loss: 0.9094
# Validation Accuracy: 0.7733
# Epoch [72/150], Loss: 0.7043
# Train Accuracy: 0.7829
# Validation Loss: 0.9287
# Validation Accuracy: 0.7333
# Epoch [73/150], Loss: 0.6883
# Train Accuracy: 0.8029
# Validation Loss: 0.9247
# Validation Accuracy: 0.7267
# Epoch [74/150], Loss: 0.6765
# Train Accuracy: 0.8029
# Validation Loss: 0.9122
# Validation Accuracy: 0.7800
# Epoch [75/150], Loss: 0.6747
# Train Accuracy: 0.7971
# Validation Loss: 0.9001
# Validation Accuracy: 0.7467
# Epoch [76/150], Loss: 0.6791
# Train Accuracy: 0.8029
# Validation Loss: 0.9074
# Validation Accuracy: 0.7600
# Epoch [77/150], Loss: 0.6684
# Train Accuracy: 0.8086
# Validation Loss: 0.9212
# Validation Accuracy: 0.7333
# Epoch [78/150], Loss: 0.6594
# Train Accuracy: 0.8086
# Validation Loss: 0.8839
# Validation Accuracy: 0.7467
# Epoch [79/150], Loss: 0.6606
# Train Accuracy: 0.8114
# Validation Loss: 0.8979
# Validation Accuracy: 0.7667
# Epoch [80/150], Loss: 0.6642
# Train Accuracy: 0.8057
# Validation Loss: 0.8969
# Validation Accuracy: 0.7333
# Epoch [81/150], Loss: 0.6558
# Train Accuracy: 0.8171
# Validation Loss: 0.8828
# Validation Accuracy: 0.7600
# Epoch [82/150], Loss: 0.6434
# Train Accuracy: 0.8114
# Validation Loss: 0.8834
# Validation Accuracy: 0.7600
# Epoch [83/150], Loss: 0.6446
# Train Accuracy: 0.8171
# Validation Loss: 0.8717
# Validation Accuracy: 0.7733
# Epoch [84/150], Loss: 0.6303
# Train Accuracy: 0.8114
# Validation Loss: 0.8644
# Validation Accuracy: 0.7533
# Epoch [85/150], Loss: 0.6300
# Train Accuracy: 0.8143
# Validation Loss: 0.8650
# Validation Accuracy: 0.7667
# Epoch [86/150], Loss: 0.6175
# Train Accuracy: 0.8229
# Validation Loss: 0.8605
# Validation Accuracy: 0.7400
# Epoch [87/150], Loss: 0.6200
# Train Accuracy: 0.8200
# Validation Loss: 0.8945
# Validation Accuracy: 0.7733
# Epoch [88/150], Loss: 0.6111
# Train Accuracy: 0.8229
# Validation Loss: 0.8477
# Validation Accuracy: 0.7533
# Epoch [89/150], Loss: 0.6162
# Train Accuracy: 0.8286
# Validation Loss: 0.8527
# Validation Accuracy: 0.7733
# Epoch [90/150], Loss: 0.6078
# Train Accuracy: 0.8314
# Validation Loss: 0.8582
# Validation Accuracy: 0.7600
# Epoch [91/150], Loss: 0.6034
# Train Accuracy: 0.8143
# Validation Loss: 0.8451
# Validation Accuracy: 0.7733
# Epoch [92/150], Loss: 0.5890
# Train Accuracy: 0.8343
# Validation Loss: 0.8419
# Validation Accuracy: 0.7733
# Epoch [93/150], Loss: 0.5907
# Train Accuracy: 0.8286
# Validation Loss: 0.8518
# Validation Accuracy: 0.7733
# Epoch [94/150], Loss: 0.5845
# Train Accuracy: 0.8429
# Validation Loss: 0.8302
# Validation Accuracy: 0.7600
# Epoch [95/150], Loss: 0.5788
# Train Accuracy: 0.8486
# Validation Loss: 0.8186
# Validation Accuracy: 0.7733
# Epoch [96/150], Loss: 0.5828
# Train Accuracy: 0.8286
# Validation Loss: 0.8476
# Validation Accuracy: 0.7467
# Epoch [97/150], Loss: 0.5712
# Train Accuracy: 0.8457
# Validation Loss: 0.8198
# Validation Accuracy: 0.7667
# Epoch [98/150], Loss: 0.5693
# Train Accuracy: 0.8486
# Validation Loss: 0.8247
# Validation Accuracy: 0.7600
# Epoch [99/150], Loss: 0.5693
# Train Accuracy: 0.8600
# Validation Loss: 0.8391
# Validation Accuracy: 0.7667
# Epoch [100/150], Loss: 0.5665
# Train Accuracy: 0.8343
# Validation Loss: 0.8170
# Validation Accuracy: 0.7667
# Epoch [101/150], Loss: 0.5644
# Train Accuracy: 0.8429
# Validation Loss: 0.8117
# Validation Accuracy: 0.7733
# Epoch [102/150], Loss: 0.5583
# Train Accuracy: 0.8600
# Validation Loss: 0.8136
# Validation Accuracy: 0.7533
# Epoch [103/150], Loss: 0.5540
# Train Accuracy: 0.8629
# Validation Loss: 0.8078
# Validation Accuracy: 0.7733
# Epoch [104/150], Loss: 0.5474
# Train Accuracy: 0.8571
# Validation Loss: 0.8127
# Validation Accuracy: 0.7667
# Epoch [105/150], Loss: 0.5388
# Train Accuracy: 0.8543
# Validation Loss: 0.8042
# Validation Accuracy: 0.7867
# Epoch [106/150], Loss: 0.5413
# Train Accuracy: 0.8600
# Validation Loss: 0.8017
# Validation Accuracy: 0.7533
# Epoch [107/150], Loss: 0.5339
# Train Accuracy: 0.8571
# Validation Loss: 0.8106
# Validation Accuracy: 0.7667
# Epoch [108/150], Loss: 0.5320
# Train Accuracy: 0.8714
# Validation Loss: 0.7938
# Validation Accuracy: 0.7800
# Epoch [109/150], Loss: 0.5371
# Train Accuracy: 0.8743
# Validation Loss: 0.8091
# Validation Accuracy: 0.7800
# Epoch [110/150], Loss: 0.5346
# Train Accuracy: 0.8657
# Validation Loss: 0.7829
# Validation Accuracy: 0.7800
# Epoch [111/150], Loss: 0.5214
# Train Accuracy: 0.8629
# Validation Loss: 0.7920
# Validation Accuracy: 0.7800
# Epoch [112/150], Loss: 0.5279
# Train Accuracy: 0.8629
# Validation Loss: 0.7814
# Validation Accuracy: 0.7733
# Epoch [113/150], Loss: 0.5239
# Train Accuracy: 0.8714
# Validation Loss: 0.8015
# Validation Accuracy: 0.7733
# Epoch [114/150], Loss: 0.5135
# Train Accuracy: 0.8743
# Validation Loss: 0.7701
# Validation Accuracy: 0.7533
# Epoch [115/150], Loss: 0.5189
# Train Accuracy: 0.8714
# Validation Loss: 0.8002
# Validation Accuracy: 0.7733
# Epoch [116/150], Loss: 0.5102
# Train Accuracy: 0.8743
# Validation Loss: 0.7796
# Validation Accuracy: 0.7800
# Epoch [117/150], Loss: 0.5124
# Train Accuracy: 0.8686
# Validation Loss: 0.7897
# Validation Accuracy: 0.7733
# Epoch [118/150], Loss: 0.5009
# Train Accuracy: 0.8743
# Validation Loss: 0.7688
# Validation Accuracy: 0.7800
# Epoch [119/150], Loss: 0.4977
# Train Accuracy: 0.8686
# Validation Loss: 0.7968
# Validation Accuracy: 0.7600
# Epoch [120/150], Loss: 0.5048
# Train Accuracy: 0.8629
# Validation Loss: 0.7651
# Validation Accuracy: 0.7667
# Epoch [121/150], Loss: 0.5064
# Train Accuracy: 0.8800
# Validation Loss: 0.7853
# Validation Accuracy: 0.7667
# Epoch [122/150], Loss: 0.4982
# Train Accuracy: 0.8743
# Validation Loss: 0.7517
# Validation Accuracy: 0.7800
# Epoch [123/150], Loss: 0.4923
# Train Accuracy: 0.8857
# Validation Loss: 0.8065
# Validation Accuracy: 0.7733
# Epoch [124/150], Loss: 0.4847
# Train Accuracy: 0.8771
# Validation Loss: 0.7505
# Validation Accuracy: 0.7867
# Epoch [125/150], Loss: 0.4872
# Train Accuracy: 0.8829
# Validation Loss: 0.7649
# Validation Accuracy: 0.7867
# Epoch [126/150], Loss: 0.4852
# Train Accuracy: 0.8914
# Validation Loss: 0.7688
# Validation Accuracy: 0.7800
# Epoch [127/150], Loss: 0.4772
# Train Accuracy: 0.8857
# Validation Loss: 0.7520
# Validation Accuracy: 0.7800
# Epoch [128/150], Loss: 0.4729
# Train Accuracy: 0.9029
# Validation Loss: 0.7631
# Validation Accuracy: 0.7933
# Epoch [129/150], Loss: 0.4810
# Train Accuracy: 0.8886
# Validation Loss: 0.7451
# Validation Accuracy: 0.7867
# Epoch [130/150], Loss: 0.4749
# Train Accuracy: 0.8886
# Validation Loss: 0.7609
# Validation Accuracy: 0.7800
# Epoch [131/150], Loss: 0.4708
# Train Accuracy: 0.8829
# Validation Loss: 0.7473
# Validation Accuracy: 0.7733
# Epoch [132/150], Loss: 0.4641
# Train Accuracy: 0.8971
# Validation Loss: 0.7504
# Validation Accuracy: 0.7667
# Epoch [133/150], Loss: 0.4650
# Train Accuracy: 0.8943
# Validation Loss: 0.7404
# Validation Accuracy: 0.7667
# Epoch [134/150], Loss: 0.4639
# Train Accuracy: 0.9029
# Validation Loss: 0.7624
# Validation Accuracy: 0.7800
# Epoch [135/150], Loss: 0.4579
# Train Accuracy: 0.8914
# Validation Loss: 0.7469
# Validation Accuracy: 0.7933
# Epoch [136/150], Loss: 0.4620
# Train Accuracy: 0.8971
# Validation Loss: 0.7357
# Validation Accuracy: 0.7867
# Epoch [137/150], Loss: 0.4545
# Train Accuracy: 0.8886
# Validation Loss: 0.7423
# Validation Accuracy: 0.7867
# Epoch [138/150], Loss: 0.4541
# Train Accuracy: 0.9029
# Validation Loss: 0.7345
# Validation Accuracy: 0.7800
# Epoch [139/150], Loss: 0.4501
# Train Accuracy: 0.8971
# Validation Loss: 0.7358
# Validation Accuracy: 0.7800
# Epoch [140/150], Loss: 0.4639
# Train Accuracy: 0.8857
# Validation Loss: 0.7416
# Validation Accuracy: 0.7733
# Epoch [141/150], Loss: 0.4511
# Train Accuracy: 0.8943
# Validation Loss: 0.7387
# Validation Accuracy: 0.7800
# Epoch [142/150], Loss: 0.4445
# Train Accuracy: 0.8886
# Validation Loss: 0.7402
# Validation Accuracy: 0.7733
# Epoch [143/150], Loss: 0.4423
# Train Accuracy: 0.9114
# Validation Loss: 0.7221
# Validation Accuracy: 0.7800
# Epoch [144/150], Loss: 0.4355
# Train Accuracy: 0.9171
# Validation Loss: 0.7505
# Validation Accuracy: 0.7800
# Epoch [145/150], Loss: 0.4306
# Train Accuracy: 0.9057
# Validation Loss: 0.7259
# Validation Accuracy: 0.7933
# Epoch [146/150], Loss: 0.4314
# Train Accuracy: 0.9114
# Validation Loss: 0.7322
# Validation Accuracy: 0.7867
# Epoch [147/150], Loss: 0.4356
# Train Accuracy: 0.8971
# Validation Loss: 0.7282
# Validation Accuracy: 0.7933
# Epoch [148/150], Loss: 0.4336
# Train Accuracy: 0.9114
# Validation Loss: 0.7176
# Validation Accuracy: 0.7933
# Epoch [149/150], Loss: 0.4274
# Train Accuracy: 0.9171
# Validation Loss: 0.7320
# Validation Accuracy: 0.7800
# Epoch [150/150], Loss: 0.4232
# Train Accuracy: 0.9200
# Validation Loss: 0.7259
# Validation Accuracy: 0.7800
# Text(0.5, 1.0, 'Validation Accuracy over Epochs')

# %%
import torch
import torch.optim as optim
import torch.nn as nn
from sklearn.metrics import accuracy_score

# モデルのインスタンス化
N_u = 130  # 入力次元数 (77, 130 の形状から130)
N_y = len(np.unique(labels))  # クラス数
N_x = 200  # リザバーのサイズ (例として200に設定)

model = ESN(N_u=N_u, N_y=N_y, N_x=N_x)

# 最適化器と損失関数の設定
optimizer = optim.Adam(model.parameters(), lr=0.01)
criterion = nn.CrossEntropyLoss()

# 損失を記録するリスト
train_losses = []
val_losses = []

# 精度を記録するリスト
train_accuracies = []
val_accuracies = []

# 訓練ループ
num_epochs = 150
for epoch in range(num_epochs):
    model.train()  # 訓練モード
    train_outputs = [] # 混同行列用
    train_labels = [] # 混同行列用
    running_loss = 0.0

    # 訓練データをバッチごとに処理
    for batch_features, batch_labels in train_loader:
        optimizer.zero_grad()

        # 順伝播
        outputs = model(batch_features)

        # 順伝播時に出力形状を確認
        outputs = model(batch_features)
        # 各チャネルに対して最も確率が高いクラスを選択
        outputs = torch.mean(outputs, dim=1)

        # 損失計算
        loss = criterion(outputs, batch_labels)

        # バックプロパゲーション
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

        train_outputs.extend(torch.argmax(outputs, dim=1).tolist())
        train_labels.extend(batch_labels.tolist())

    # エポック毎の平均損失を表示
    avg_train_loss = running_loss / len(train_loader)
    train_losses.append(avg_train_loss)
    print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {avg_train_loss:.4f}")
    trin_accuracy = accuracy_score(train_labels, train_outputs)
    print(f"Train Accuracy: {trin_accuracy:.4f}")
    train_accuracies.append(trin_accuracy)

    # 検証
    model.eval()  # 評価モード
    val_outputs = []
    val_labels = []
    running_val_loss = 0.0
    with torch.no_grad():
        for batch_features, batch_labels in val_loader:
            # 順伝播
            outputs = model(batch_features)
            outputs = torch.mean(outputs, dim=1)
            _, predicted = torch.max(outputs, 1)
            val_outputs.extend(predicted.numpy())
            val_labels.extend(batch_labels.numpy())

            loss = criterion(outputs, batch_labels)
            running_val_loss += loss.item()

    avg_val_loss = running_val_loss / len(val_loader)
    val_losses.append(avg_val_loss)
    print(f"Validation Loss: {avg_val_loss:.4f}")


    val_accuracy = accuracy_score(val_labels, val_outputs)
    print(f"Validation Accuracy: {val_accuracy:.4f}")
    val_accuracies.append(val_accuracy)

from sklearn.metrics import confusion_matrix
import seaborn as sns

# 混同行列を計算
cm = confusion_matrix(val_labels, val_outputs)

# 訓練データに対する混同行列
cm_train = confusion_matrix(train_labels, train_outputs)

# 訓練データの混同行列を描画
plt.figure(figsize=(8, 6))
sns.heatmap(cm_train, annot=True, fmt="d", cmap="Blues", xticklabels=[str(i) for i in range(10)], yticklabels=[str(i) for i in range(10)])
plt.xlabel('predict')
plt.ylabel('real')
plt.title('con_train')
plt.show()

# 混同行列を描画
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=[str(i) for i in range(10)], yticklabels=[str(i) for i in range(10)])
plt.xlabel('predict')
plt.ylabel('real')
plt.title('con_val')
plt.show()


# 訓練損失
plt.figure(figsize=(8, 6))
plt.plot(range(1, num_epochs+1), train_losses, label='Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# 検証損失
plt.figure(figsize=(8, 6))
plt.plot(range(1, num_epochs+1), val_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Validation Loss over Epochs')
plt.legend()

# 訓練制度
plt.figure(figsize=(8, 6))
plt.plot(range(1, num_epochs + 1), train_accuracies, label='Training Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training Accuracy over Epochs')
plt.legend()
plt.show()

# 検証制度
plt.figure(figsize=(8, 6))
plt.plot(range(1, num_epochs + 1), val_accuracies, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Validation Accuracy over Epochs')
# Out:
# Epoch [1/150], Loss: 9.4259
# Train Accuracy: 0.1343
# Validation Loss: 5.6807
# Validation Accuracy: 0.1733
# Epoch [2/150], Loss: 4.9438
# Train Accuracy: 0.1314
# Validation Loss: 3.4789
# Validation Accuracy: 0.0867
# Epoch [3/150], Loss: 3.3555
# Train Accuracy: 0.1400
# Validation Loss: 2.7504
# Validation Accuracy: 0.2467
# Epoch [4/150], Loss: 2.5779
# Train Accuracy: 0.2686
# Validation Loss: 2.6191
# Validation Accuracy: 0.2067
# Epoch [5/150], Loss: 2.2308
# Train Accuracy: 0.3171
# Validation Loss: 2.3087
# Validation Accuracy: 0.2733
# Epoch [6/150], Loss: 2.0500
# Train Accuracy: 0.3543
# Validation Loss: 2.1803
# Validation Accuracy: 0.2667
# Epoch [7/150], Loss: 1.8974
# Train Accuracy: 0.3571
# Validation Loss: 2.0416
# Validation Accuracy: 0.3400
# Epoch [8/150], Loss: 1.7816
# Train Accuracy: 0.3943
# Validation Loss: 1.8928
# Validation Accuracy: 0.3800
# Epoch [9/150], Loss: 1.6594
# Train Accuracy: 0.4543
# Validation Loss: 1.8448
# Validation Accuracy: 0.3867
# Epoch [10/150], Loss: 1.5782
# Train Accuracy: 0.4714
# Validation Loss: 1.7664
# Validation Accuracy: 0.3800
# Epoch [11/150], Loss: 1.5134
# Train Accuracy: 0.4971
# Validation Loss: 1.7030
# Validation Accuracy: 0.4267
# Epoch [12/150], Loss: 1.4747
# Train Accuracy: 0.4971
# Validation Loss: 1.6347
# Validation Accuracy: 0.4267
# Epoch [13/150], Loss: 1.4396
# Train Accuracy: 0.5171
# Validation Loss: 1.6293
# Validation Accuracy: 0.4400
# Epoch [14/150], Loss: 1.3918
# Train Accuracy: 0.5200
# Validation Loss: 1.5182
# Validation Accuracy: 0.4800
# Epoch [15/150], Loss: 1.3370
# Train Accuracy: 0.5571
# Validation Loss: 1.5647
# Validation Accuracy: 0.4733
# Epoch [16/150], Loss: 1.3023
# Train Accuracy: 0.5686
# Validation Loss: 1.4303
# Validation Accuracy: 0.5067
# Epoch [17/150], Loss: 1.2468
# Train Accuracy: 0.6143
# Validation Loss: 1.4097
# Validation Accuracy: 0.5000
# Epoch [18/150], Loss: 1.2223
# Train Accuracy: 0.5914
# Validation Loss: 1.3906
# Validation Accuracy: 0.5333
# Epoch [19/150], Loss: 1.1939
# Train Accuracy: 0.5971
# Validation Loss: 1.3311
# Validation Accuracy: 0.5733
# Epoch [20/150], Loss: 1.1660
# Train Accuracy: 0.6257
# Validation Loss: 1.3005
# Validation Accuracy: 0.5467
# Epoch [21/150], Loss: 1.1259
# Train Accuracy: 0.6114
# Validation Loss: 1.3207
# Validation Accuracy: 0.5467
# Epoch [22/150], Loss: 1.0939
# Train Accuracy: 0.6571
# Validation Loss: 1.2562
# Validation Accuracy: 0.5867
# Epoch [23/150], Loss: 1.0931
# Train Accuracy: 0.6314
# Validation Loss: 1.2494
# Validation Accuracy: 0.5800
# Epoch [24/150], Loss: 1.0556
# Train Accuracy: 0.6657
# Validation Loss: 1.1976
# Validation Accuracy: 0.6200
# Epoch [25/150], Loss: 1.0465
# Train Accuracy: 0.6486
# Validation Loss: 1.2223
# Validation Accuracy: 0.6200
# Epoch [26/150], Loss: 1.0318
# Train Accuracy: 0.6743
# Validation Loss: 1.2053
# Validation Accuracy: 0.5800
# Epoch [27/150], Loss: 1.0002
# Train Accuracy: 0.6829
# Validation Loss: 1.1469
# Validation Accuracy: 0.6400
# Epoch [28/150], Loss: 0.9872
# Train Accuracy: 0.6771
# Validation Loss: 1.2012
# Validation Accuracy: 0.6067
# Epoch [29/150], Loss: 0.9672
# Train Accuracy: 0.6829
# Validation Loss: 1.1005
# Validation Accuracy: 0.6667
# Epoch [30/150], Loss: 0.9410
# Train Accuracy: 0.6943
# Validation Loss: 1.1549
# Validation Accuracy: 0.6267
# Epoch [31/150], Loss: 0.9473
# Train Accuracy: 0.7143
# Validation Loss: 1.0948
# Validation Accuracy: 0.6267
# Epoch [32/150], Loss: 0.9404
# Train Accuracy: 0.6971
# Validation Loss: 1.1637
# Validation Accuracy: 0.6067
# Epoch [33/150], Loss: 0.9218
# Train Accuracy: 0.7114
# Validation Loss: 1.0803
# Validation Accuracy: 0.6333
# Epoch [34/150], Loss: 0.9108
# Train Accuracy: 0.7229
# Validation Loss: 1.0276
# Validation Accuracy: 0.6933
# Epoch [35/150], Loss: 0.8717
# Train Accuracy: 0.7314
# Validation Loss: 1.0594
# Validation Accuracy: 0.6533
# Epoch [36/150], Loss: 0.8634
# Train Accuracy: 0.7486
# Validation Loss: 1.0365
# Validation Accuracy: 0.6533
# Epoch [37/150], Loss: 0.8467
# Train Accuracy: 0.7457
# Validation Loss: 0.9912
# Validation Accuracy: 0.6867
# Epoch [38/150], Loss: 0.8452
# Train Accuracy: 0.7429
# Validation Loss: 1.0145
# Validation Accuracy: 0.6800
# Epoch [39/150], Loss: 0.8335
# Train Accuracy: 0.7429
# Validation Loss: 0.9776
# Validation Accuracy: 0.7133
# Epoch [40/150], Loss: 0.8487
# Train Accuracy: 0.7457
# Validation Loss: 1.1187
# Validation Accuracy: 0.5733
# Epoch [41/150], Loss: 0.8450
# Train Accuracy: 0.7257
# Validation Loss: 0.9707
# Validation Accuracy: 0.6933
# Epoch [42/150], Loss: 0.7960
# Train Accuracy: 0.7457
# Validation Loss: 1.0294
# Validation Accuracy: 0.6600
# Epoch [43/150], Loss: 0.7855
# Train Accuracy: 0.7714
# Validation Loss: 0.9176
# Validation Accuracy: 0.6933
# Epoch [44/150], Loss: 0.7838
# Train Accuracy: 0.7514
# Validation Loss: 0.9877
# Validation Accuracy: 0.6800
# Epoch [45/150], Loss: 0.7711
# Train Accuracy: 0.7829
# Validation Loss: 0.9394
# Validation Accuracy: 0.6933
# Epoch [46/150], Loss: 0.7707
# Train Accuracy: 0.7629
# Validation Loss: 0.9845
# Validation Accuracy: 0.6600
# Epoch [47/150], Loss: 0.7487
# Train Accuracy: 0.7571
# Validation Loss: 0.9042
# Validation Accuracy: 0.7000
# Epoch [48/150], Loss: 0.7447
# Train Accuracy: 0.7800
# Validation Loss: 0.9044
# Validation Accuracy: 0.7067
# Epoch [49/150], Loss: 0.7350
# Train Accuracy: 0.7686
# Validation Loss: 0.9214
# Validation Accuracy: 0.6800
# Epoch [50/150], Loss: 0.7148
# Train Accuracy: 0.7857
# Validation Loss: 0.9812
# Validation Accuracy: 0.6733
# Epoch [51/150], Loss: 0.7081
# Train Accuracy: 0.7829
# Validation Loss: 0.8642
# Validation Accuracy: 0.7133
# Epoch [52/150], Loss: 0.6976
# Train Accuracy: 0.7914
# Validation Loss: 0.9237
# Validation Accuracy: 0.7000
# Epoch [53/150], Loss: 0.6969
# Train Accuracy: 0.7771
# Validation Loss: 0.8515
# Validation Accuracy: 0.7200
# Epoch [54/150], Loss: 0.6894
# Train Accuracy: 0.8057
# Validation Loss: 0.8835
# Validation Accuracy: 0.7133
# Epoch [55/150], Loss: 0.6751
# Train Accuracy: 0.8229
# Validation Loss: 0.8616
# Validation Accuracy: 0.7200
# Epoch [56/150], Loss: 0.6594
# Train Accuracy: 0.8171
# Validation Loss: 0.8432
# Validation Accuracy: 0.7133
# Epoch [57/150], Loss: 0.6623
# Train Accuracy: 0.8171
# Validation Loss: 0.8709
# Validation Accuracy: 0.7200
# Epoch [58/150], Loss: 0.6534
# Train Accuracy: 0.8343
# Validation Loss: 0.8706
# Validation Accuracy: 0.7133
# Epoch [59/150], Loss: 0.6688
# Train Accuracy: 0.7943
# Validation Loss: 0.8565
# Validation Accuracy: 0.7200
# Epoch [60/150], Loss: 0.6395
# Train Accuracy: 0.8371
# Validation Loss: 0.8548
# Validation Accuracy: 0.7200
# Epoch [61/150], Loss: 0.6509
# Train Accuracy: 0.8229
# Validation Loss: 0.8288
# Validation Accuracy: 0.7200
# Epoch [62/150], Loss: 0.6462
# Train Accuracy: 0.8200
# Validation Loss: 0.8331
# Validation Accuracy: 0.7333
# Epoch [63/150], Loss: 0.6197
# Train Accuracy: 0.8200
# Validation Loss: 0.7916
# Validation Accuracy: 0.7400
# Epoch [64/150], Loss: 0.6126
# Train Accuracy: 0.8286
# Validation Loss: 0.8695
# Validation Accuracy: 0.7267
# Epoch [65/150], Loss: 0.5990
# Train Accuracy: 0.8514
# Validation Loss: 0.7957
# Validation Accuracy: 0.7733
# Epoch [66/150], Loss: 0.5922
# Train Accuracy: 0.8486
# Validation Loss: 0.8757
# Validation Accuracy: 0.7067
# Epoch [67/150], Loss: 0.5892
# Train Accuracy: 0.8257
# Validation Loss: 0.7792
# Validation Accuracy: 0.7600
# Epoch [68/150], Loss: 0.6186
# Train Accuracy: 0.8057
# Validation Loss: 0.8708
# Validation Accuracy: 0.7000
# Epoch [69/150], Loss: 0.5891
# Train Accuracy: 0.8286
# Validation Loss: 0.7980
# Validation Accuracy: 0.7467
# Epoch [70/150], Loss: 0.5865
# Train Accuracy: 0.8457
# Validation Loss: 0.7934
# Validation Accuracy: 0.7467
# Epoch [71/150], Loss: 0.5789
# Train Accuracy: 0.8486
# Validation Loss: 0.7703
# Validation Accuracy: 0.7667
# Epoch [72/150], Loss: 0.5551
# Train Accuracy: 0.8629
# Validation Loss: 0.8114
# Validation Accuracy: 0.7400
# Epoch [73/150], Loss: 0.5609
# Train Accuracy: 0.8571
# Validation Loss: 0.7503
# Validation Accuracy: 0.7533
# Epoch [74/150], Loss: 0.5506
# Train Accuracy: 0.8743
# Validation Loss: 0.7843
# Validation Accuracy: 0.7467
# Epoch [75/150], Loss: 0.5534
# Train Accuracy: 0.8514
# Validation Loss: 0.7620
# Validation Accuracy: 0.7667
# Epoch [76/150], Loss: 0.5414
# Train Accuracy: 0.8600
# Validation Loss: 0.8070
# Validation Accuracy: 0.7267
# Epoch [77/150], Loss: 0.5480
# Train Accuracy: 0.8543
# Validation Loss: 0.7347
# Validation Accuracy: 0.7800
# Epoch [78/150], Loss: 0.5324
# Train Accuracy: 0.8686
# Validation Loss: 0.7924
# Validation Accuracy: 0.7400
# Epoch [79/150], Loss: 0.5310
# Train Accuracy: 0.8743
# Validation Loss: 0.7533
# Validation Accuracy: 0.7800
# Epoch [80/150], Loss: 0.5346
# Train Accuracy: 0.8400
# Validation Loss: 0.7299
# Validation Accuracy: 0.8000
# Epoch [81/150], Loss: 0.5300
# Train Accuracy: 0.8571
# Validation Loss: 0.7616
# Validation Accuracy: 0.7467
# Epoch [82/150], Loss: 0.5142
# Train Accuracy: 0.8714
# Validation Loss: 0.7186
# Validation Accuracy: 0.7733
# Epoch [83/150], Loss: 0.4990
# Train Accuracy: 0.8857
# Validation Loss: 0.7738
# Validation Accuracy: 0.7733
# Epoch [84/150], Loss: 0.5043
# Train Accuracy: 0.8714
# Validation Loss: 0.7095
# Validation Accuracy: 0.7867
# Epoch [85/150], Loss: 0.4967
# Train Accuracy: 0.8800
# Validation Loss: 0.7499
# Validation Accuracy: 0.7600
# Epoch [86/150], Loss: 0.5047
# Train Accuracy: 0.8714
# Validation Loss: 0.8053
# Validation Accuracy: 0.7267
# Epoch [87/150], Loss: 0.4942
# Train Accuracy: 0.8829
# Validation Loss: 0.7062
# Validation Accuracy: 0.7933
# Epoch [88/150], Loss: 0.4835
# Train Accuracy: 0.8943
# Validation Loss: 0.7057
# Validation Accuracy: 0.7867
# Epoch [89/150], Loss: 0.4752
# Train Accuracy: 0.8914
# Validation Loss: 0.7159
# Validation Accuracy: 0.7933
# Epoch [90/150], Loss: 0.4772
# Train Accuracy: 0.8914
# Validation Loss: 0.7064
# Validation Accuracy: 0.8067
# Epoch [91/150], Loss: 0.4685
# Train Accuracy: 0.8771
# Validation Loss: 0.7146
# Validation Accuracy: 0.7600
# Epoch [92/150], Loss: 0.4708
# Train Accuracy: 0.8829
# Validation Loss: 0.6988
# Validation Accuracy: 0.7933
# Epoch [93/150], Loss: 0.4698
# Train Accuracy: 0.8829
# Validation Loss: 0.7419
# Validation Accuracy: 0.7667
# Epoch [94/150], Loss: 0.4683
# Train Accuracy: 0.8914
# Validation Loss: 0.7468
# Validation Accuracy: 0.7533
# Epoch [95/150], Loss: 0.4644
# Train Accuracy: 0.8629
# Validation Loss: 0.6964
# Validation Accuracy: 0.7867
# Epoch [96/150], Loss: 0.4640
# Train Accuracy: 0.8857
# Validation Loss: 0.7161
# Validation Accuracy: 0.7533
# Epoch [97/150], Loss: 0.4447
# Train Accuracy: 0.9229
# Validation Loss: 0.6736
# Validation Accuracy: 0.8067
# Epoch [98/150], Loss: 0.4461
# Train Accuracy: 0.8829
# Validation Loss: 0.7045
# Validation Accuracy: 0.8067
# Epoch [99/150], Loss: 0.4452
# Train Accuracy: 0.8971
# Validation Loss: 0.6942
# Validation Accuracy: 0.7933
# Epoch [100/150], Loss: 0.4453
# Train Accuracy: 0.8943
# Validation Loss: 0.7382
# Validation Accuracy: 0.7600
# Epoch [101/150], Loss: 0.4590
# Train Accuracy: 0.8829
# Validation Loss: 0.6806
# Validation Accuracy: 0.8000
# Epoch [102/150], Loss: 0.4326
# Train Accuracy: 0.9086
# Validation Loss: 0.7052
# Validation Accuracy: 0.8067
# Epoch [103/150], Loss: 0.4275
# Train Accuracy: 0.9171
# Validation Loss: 0.6633
# Validation Accuracy: 0.8000
# Epoch [104/150], Loss: 0.4330
# Train Accuracy: 0.9000
# Validation Loss: 0.7152
# Validation Accuracy: 0.7933
# Epoch [105/150], Loss: 0.4187
# Train Accuracy: 0.8971
# Validation Loss: 0.6752
# Validation Accuracy: 0.8200
# Epoch [106/150], Loss: 0.4320
# Train Accuracy: 0.8914
# Validation Loss: 0.6907
# Validation Accuracy: 0.7533
# Epoch [107/150], Loss: 0.4173
# Train Accuracy: 0.8914
# Validation Loss: 0.6966
# Validation Accuracy: 0.7933
# Epoch [108/150], Loss: 0.4019
# Train Accuracy: 0.9171
# Validation Loss: 0.6659
# Validation Accuracy: 0.8267
# Epoch [109/150], Loss: 0.4055
# Train Accuracy: 0.9086
# Validation Loss: 0.6909
# Validation Accuracy: 0.7800
# Epoch [110/150], Loss: 0.3976
# Train Accuracy: 0.9143
# Validation Loss: 0.6358
# Validation Accuracy: 0.8200
# Epoch [111/150], Loss: 0.3965
# Train Accuracy: 0.9143
# Validation Loss: 0.6928
# Validation Accuracy: 0.8000
# Epoch [112/150], Loss: 0.3946
# Train Accuracy: 0.9114
# Validation Loss: 0.6506
# Validation Accuracy: 0.8000
# Epoch [113/150], Loss: 0.4006
# Train Accuracy: 0.9029
# Validation Loss: 0.6451
# Validation Accuracy: 0.8000
# Epoch [114/150], Loss: 0.3978
# Train Accuracy: 0.9000
# Validation Loss: 0.6827
# Validation Accuracy: 0.8000
# Epoch [115/150], Loss: 0.3857
# Train Accuracy: 0.9143
# Validation Loss: 0.6277
# Validation Accuracy: 0.8333
# Epoch [116/150], Loss: 0.3997
# Train Accuracy: 0.9114
# Validation Loss: 0.6836
# Validation Accuracy: 0.7933
# Epoch [117/150], Loss: 0.3810
# Train Accuracy: 0.9286
# Validation Loss: 0.6511
# Validation Accuracy: 0.8000
# Epoch [118/150], Loss: 0.3864
# Train Accuracy: 0.9171
# Validation Loss: 0.6530
# Validation Accuracy: 0.8000
# Epoch [119/150], Loss: 0.3879
# Train Accuracy: 0.9143
# Validation Loss: 0.6718
# Validation Accuracy: 0.7667
# Epoch [120/150], Loss: 0.4025
# Train Accuracy: 0.9057
# Validation Loss: 0.6732
# Validation Accuracy: 0.8133
# Epoch [121/150], Loss: 0.3853
# Train Accuracy: 0.9114
# Validation Loss: 0.6502
# Validation Accuracy: 0.8067
# Epoch [122/150], Loss: 0.3728
# Train Accuracy: 0.9200
# Validation Loss: 0.6348
# Validation Accuracy: 0.8067
# Epoch [123/150], Loss: 0.3609
# Train Accuracy: 0.9371
# Validation Loss: 0.6455
# Validation Accuracy: 0.8067
# Epoch [124/150], Loss: 0.3557
# Train Accuracy: 0.9171
# Validation Loss: 0.6506
# Validation Accuracy: 0.8133
# Epoch [125/150], Loss: 0.3669
# Train Accuracy: 0.9229
# Validation Loss: 0.6389
# Validation Accuracy: 0.7867
# Epoch [126/150], Loss: 0.3618
# Train Accuracy: 0.9343
# Validation Loss: 0.6311
# Validation Accuracy: 0.8267
# Epoch [127/150], Loss: 0.3595
# Train Accuracy: 0.9286
# Validation Loss: 0.6872
# Validation Accuracy: 0.7733
# Epoch [128/150], Loss: 0.3525
# Train Accuracy: 0.9371
# Validation Loss: 0.6261
# Validation Accuracy: 0.8200
# Epoch [129/150], Loss: 0.3423
# Train Accuracy: 0.9314
# Validation Loss: 0.6326
# Validation Accuracy: 0.8133
# Epoch [130/150], Loss: 0.3508
# Train Accuracy: 0.9229
# Validation Loss: 0.6611
# Validation Accuracy: 0.7933
# Epoch [131/150], Loss: 0.3357
# Train Accuracy: 0.9429
# Validation Loss: 0.6061
# Validation Accuracy: 0.8200
# Epoch [132/150], Loss: 0.3571
# Train Accuracy: 0.9229
# Validation Loss: 0.6808
# Validation Accuracy: 0.7800
# Epoch [133/150], Loss: 0.3557
# Train Accuracy: 0.9171
# Validation Loss: 0.6072
# Validation Accuracy: 0.8400
# Epoch [134/150], Loss: 0.3542
# Train Accuracy: 0.9257
# Validation Loss: 0.6541
# Validation Accuracy: 0.8200
# Epoch [135/150], Loss: 0.3378
# Train Accuracy: 0.9343
# Validation Loss: 0.6078
# Validation Accuracy: 0.8333
# Epoch [136/150], Loss: 0.3472
# Train Accuracy: 0.9171
# Validation Loss: 0.6884
# Validation Accuracy: 0.7600
# Epoch [137/150], Loss: 0.3608
# Train Accuracy: 0.9086
# Validation Loss: 0.6042
# Validation Accuracy: 0.8267
# Epoch [138/150], Loss: 0.3353
# Train Accuracy: 0.9343
# Validation Loss: 0.6359
# Validation Accuracy: 0.8267
# Epoch [139/150], Loss: 0.3363
# Train Accuracy: 0.9257
# Validation Loss: 0.6340
# Validation Accuracy: 0.8000
# Epoch [140/150], Loss: 0.3176
# Train Accuracy: 0.9314
# Validation Loss: 0.6142
# Validation Accuracy: 0.8133
# Epoch [141/150], Loss: 0.3213
# Train Accuracy: 0.9371
# Validation Loss: 0.6251
# Validation Accuracy: 0.8400
# Epoch [142/150], Loss: 0.3173
# Train Accuracy: 0.9457
# Validation Loss: 0.6149
# Validation Accuracy: 0.8267
# Epoch [143/150], Loss: 0.3176
# Train Accuracy: 0.9457
# Validation Loss: 0.6266
# Validation Accuracy: 0.8200
# Epoch [144/150], Loss: 0.3199
# Train Accuracy: 0.9457
# Validation Loss: 0.6108
# Validation Accuracy: 0.8200
# Epoch [145/150], Loss: 0.3282
# Train Accuracy: 0.9343
# Validation Loss: 0.6266
# Validation Accuracy: 0.8333
# Epoch [146/150], Loss: 0.3017
# Train Accuracy: 0.9514
# Validation Loss: 0.6115
# Validation Accuracy: 0.8200
# Epoch [147/150], Loss: 0.3028
# Train Accuracy: 0.9571
# Validation Loss: 0.6178
# Validation Accuracy: 0.8267
# Epoch [148/150], Loss: 0.2960
# Train Accuracy: 0.9514
# Validation Loss: 0.5961
# Validation Accuracy: 0.8400
# Epoch [149/150], Loss: 0.3050
# Train Accuracy: 0.9514
# Validation Loss: 0.5934
# Validation Accuracy: 0.8467
# Epoch [150/150], Loss: 0.3087
# Train Accuracy: 0.9400
# Validation Loss: 0.6316
# Validation Accuracy: 0.8200
# Text(0.5, 1.0, 'Validation Accuracy over Epochs')
